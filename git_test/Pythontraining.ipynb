# %% [markdown]
# # Welcome All

# %%
3+5

print ("Hello World")
# Out:
# Hello World

# %%
import math

help(math)

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
help(math.sqrt())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c45c91b3a528> in <module>()
# ----> 1 help(math.sqrt())
#
# TypeError: sqrt() takes exactly one argument (0 given)

# %%
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(...)
#     sqrt(x)
#
#     Return the square root of x.

# %%
a=5

# %%
print(a)
# Out:
# 5

# %%
dna="ATG"

# %%
print(dna)
# Out:
# ATG

# %%
mass = 47.5
height = 24.5
age = 122
mass = mass * 2.3
age = age - 20
height = height + 20

# %%
print (mass)
# Out:
# 109.24999999999999

# %%
print (age)
# Out:
# 102

# %%
print (height)
# Out:
# 44.5

# %%
who
# Out:
# a	 age	 dna	 height	 mass	 math

# %%
del(a)

# %%
who
# Out:
# age	 dna	 height	 mass	 math

# %%
reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
who
# Out:
# Interactive namespace is empty.

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-bca0e2660b9f> in <module>()
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
help(math)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-e606f19bc963> in <module>()
# ----> 1 help(math)
#
# NameError: name 'math' is not defined

# %%
import math
help(math)
# Out:
# Help on module math:
#
# NAME
#     math
#
# MODULE REFERENCE
#     https://docs.python.org/3.6/library/math
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
#         atan(x)
#
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(...)
#         atan2(y, x)
#
#         Return the arc tangent (measured in radians) of y/x.
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(...)
#         atanh(x)
#
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(...)
#         ceil(x)
#
#         Return the ceiling of x as an Integral.
#         This is the smallest integer >= x.
#
#     copysign(...)
#         copysign(x, y)
#
#         Return a float with the magnitude (absolute value) of x but the sign
#         of y. On platforms that support signed zeros, copysign(1.0, -0.0)
#         returns -1.0.
#
#     cos(...)
#         cos(x)
#
#         Return the cosine of x (measured in radians).
#
#     cosh(...)
#         cosh(x)
#
#         Return the hyperbolic cosine of x.
#
#     degrees(...)
#         degrees(x)
#
#         Convert angle x from radians to degrees.
#
#     erf(...)
#         erf(x)
#
#         Error function at x.
#
#     erfc(...)
#         erfc(x)
#
#         Complementary error function at x.
#
#     exp(...)
#         exp(x)
#
#         Return e raised to the power of x.
#
#     expm1(...)
#         expm1(x)
#
#         Return exp(x)-1.
#         This function avoids the loss of precision involved in the direct evaluation of exp(x)-1 for small x.
#
#     fabs(...)
#         fabs(x)
#
#         Return the absolute value of the float x.
#
#     factorial(...)
#         factorial(x) -> Integral
#
#         Find x!. Raise a ValueError if x is negative or non-integral.
#
#     floor(...)
#         floor(x)
#
#         Return the floor of x as an Integral.
#         This is the largest integer <= x.
#
#     fmod(...)
#         fmod(x, y)
#
#         Return fmod(x, y), according to platform C.  x % y may differ.
#
#     frexp(...)
#         frexp(x)
#
#         Return the mantissa and exponent of x, as pair (m, e).
#         m is a float and e is an int, such that x = m * 2.**e.
#         If x is 0, m and e are both 0.  Else 0.5 <= abs(m) < 1.0.
#
#     fsum(...)
#         fsum(iterable)
#
#         Return an accurate floating point sum of values in the iterable.
#         Assumes IEEE-754 floating point arithmetic.
#
#     gamma(...)
#         gamma(x)
#
#         Gamma function at x.
#
#     gcd(...)
#         gcd(x, y) -> int
#         greatest common divisor of x and y
#
#     hypot(...)
#         hypot(x, y)
#
#         Return the Euclidean distance, sqrt(x*x + y*y).
#
#     isclose(...)
#         isclose(a, b, *, rel_tol=1e-09, abs_tol=0.0) -> bool
#
#         Determine whether two floating point numbers are close in value.
#
#            rel_tol
#                maximum difference for being considered "close", relative to the
#                magnitude of the input values
#             abs_tol
#                maximum difference for being considered "close", regardless of the
#                magnitude of the input values
#
#         Return True if a is close in value to b, and False otherwise.
#
#         For the values to be considered close, the difference between them
#         must be smaller than at least one of the tolerances.
#
#         -inf, inf and NaN behave similarly to the IEEE 754 Standard.  That
#         is, NaN is not close to anything, even itself.  inf and -inf are
#         only close to themselves.
#
#     isfinite(...)
#         isfinite(x) -> bool
#
#         Return True if x is neither an infinity nor a NaN, and False otherwise.
#
#     isinf(...)
#         isinf(x) -> bool
#
#         Return True if x is a positive or negative infinity, and False otherwise.
#
#     isnan(...)
#         isnan(x) -> bool
#
#         Return True if x is a NaN (not a number), and False otherwise.
#
#     ldexp(...)
#         ldexp(x, i)
#
#         Return x * (2**i).
#
#     lgamma(...)
#         lgamma(x)
#
#         Natural logarithm of absolute value of Gamma function at x.
#
#     log(...)
#         log(x[, base])
#
#         Return the logarithm of x to the given base.
#         If the base not specified, returns the natural logarithm (base e) of x.
#
#     log10(...)
#         log10(x)
#
#         Return the base 10 logarithm of x.
#
#     log1p(...)
#         log1p(x)
#
#         Return the natural logarithm of 1+x (base e).
#         The result is computed in a way which is accurate for x near zero.
#
#     log2(...)
#         log2(x)
#
#         Return the base 2 logarithm of x.
#
#     modf(...)
#         modf(x)
#
#         Return the fractional and integer parts of x.  Both results carry the sign
#         of x and are floats.
#
#     pow(...)
#         pow(x, y)
#
#         Return x**y (x to the power of y).
#
#     radians(...)
#         radians(x)
#
#         Convert angle x from degrees to radians.
#
#     sin(...)
#         sin(x)
#
#         Return the sine of x (measured in radians).
#
#     sinh(...)
#         sinh(x)
#
#         Return the hyperbolic sine of x.
#
#     sqrt(...)
#         sqrt(x)
#
#         Return the square root of x.
#
#     tan(...)
#         tan(x)
#
#         Return the tangent of x (measured in radians).
#
#     tanh(...)
#         tanh(x)
#
#         Return the hyperbolic tangent of x.
#
#     trunc(...)
#         trunc(x:Real) -> Integral
#
#         Truncates x to the nearest Integral toward 0. Uses the __trunc__ magic method.
#
# DATA
#     e = 2.718281828459045
#     inf = inf
#     nan = nan
#     pi = 3.141592653589793
#     tau = 6.283185307179586
#
# FILE
#     /Users/alwachin/anaconda3/lib/python3.6/lib-dynload/math.cpython-36m-darwin.so

# %%
a =5
print(a)
# Out:
# 5

# %%
dna="ATG"
print(dna)
# Out:
# ATG

# %%
type(a)
# Out:
# int

# %%
type(dna)
# Out:
# str

# %%
a=5.7

# %%
print(a)
# Out:
# 5.7

# %%
type(a)
# Out:
# float

# %% [markdown]
# str()-to convert to string data type
#
# int()-to convert to int data type
#
# float()- to convert to flout data type

# %%
list=["Afganistan", "Asia", 4,5, 1987, 6.2]

# %%
print(list)
# Out:
# ['Afganistan', 'Asia', 4, 5, 1987, 6.2]

# %%
list[2]
# Out:
# 4

# %% [markdown]
# # List
# #list is an ordered sequence of objects
# #indexing start from zero
# #list are mutable
# list[2:6]

# %%
list[3]=187.55

# %%
print(list)
# Out:
# ['Afganistan', 'Asia', 4, 187.55, 1987, 6.2]

# %% [markdown]
# # tuple
# #tuple are ordered sequence of objects
# #tuple are indexed and the index start from zero
# #tuple are immutable
# tuple=('Afganistan', 'Asia', 4, 187.55, 1987, 6.2)

# %%
### print(tuple)

# %%
tuple[0]
# Out:
# 'Afganistan'

# %%
tuple[3]
# Out:
# 187.55

# %%
tuple[3]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-c7089f6209d2> in <module>()
# ----> 1 tuple[3]=5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# # Dictionary
# #dictionary is an unordered sequence of objects
# #Dictionary contations key:valu pair

# %%
dict ={1:"a", 2:"b",dna:"ATG"}
dict[dna]
# Out:
# 'ATG'

# %%
my_order={'menuItems':["chicken","soup"],'menuTyple':["Solid","Liquid"],'menuCost':[4.99,2.99]}

print(my_order)
# Out:
# {'menuItems': ['chicken', 'soup'], 'menuTyple': ['Solid', 'Liquid'], 'menuCost': [4.99, 2.99]}

# %% [markdown]
# # pandas
# import pandas as pd

# %%
My_Order = pd.DataFrame(data=my_order)

# %%
print(My_Order)
# Out:
#    menuCost menuItems menuTyple
# 0      4.99   chicken     Solid
# 1      2.99      soup    Liquid

# %%
my_file=pd.read_table("gapminder.txt")

# %%
my_file
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# 13        Albania    Europe  1957   59.280   1476505  1942.284244
# 14        Albania    Europe  1962   64.820   1728137  2312.888958
# 15        Albania    Europe  1967   66.220   1984060  2760.196931
# 16        Albania    Europe  1972   67.690   2263554  3313.422188
# 17        Albania    Europe  1977   68.930   2509048  3533.003910
# 18        Albania    Europe  1982   70.420   2780097  3630.880722
# 19        Albania    Europe  1987   72.000   3075321  3738.932735
# 20        Albania    Europe  1992   71.581   3326498  2497.437901
# 9764   44.0   37.00   0.006612  0.0900    ...     2018-01-17T03:37:01.484Z
# 9765   18.0  156.00   0.017030  0.0700    ...     2018-01-16T23:58:01.745Z
# 9766   22.0   59.00   0.013170  0.1300    ...     2018-01-16T23:06:13.545Z
# 9767   14.0  195.00   0.017300  0.0500    ...     2018-01-16T23:44:01.709Z
# 9768    NaN     NaN        NaN  1.2700    ...     2018-02-12T23:16:51.040Z
# 9769   25.0   88.00   0.242300  0.1600    ...     2018-01-17T00:05:39.050Z
#
#                                        place          type horizontalError  \
# 0              7km S of Captain Cook, Hawaii    earthquake            0.77
# 1                  17km NNE of Healy, Alaska    earthquake             NaN
# 2                    6km SE of Fallbrook, CA    earthquake            1.15
# 3            71km ENE of Maneadero, B.C., MX    earthquake            0.69
# 4          16km NW of Bridgeport, California    earthquake             NaN
# 5                 26km NNE of Badger, Alaska    earthquake             NaN
# 6                10km WNW of The Geysers, CA    earthquake            0.49
# 7                             Western Xizang    earthquake            9.00
# 8                   3km NNW of El Centro, CA    earthquake            0.32
# 9                97km NNW of Nikiski, Alaska    earthquake             NaN
# 10               39km SW of Cantwell, Alaska    earthquake             NaN
# 11                   30km NE of Oakhurst, CA    earthquake            0.40
# 12            6km NW of Lakeland Village, CA    earthquake            0.25
# 13             12km N of Borrego Springs, CA    earthquake            0.34
# 14             12km N of Borrego Springs, CA    earthquake            0.55
# 15                18km SSW of Twin Lakes, CA    earthquake            1.59
# 16               112km W of Cantwell, Alaska    earthquake             NaN
# 17                     9km NE of Aguanga, CA    earthquake            0.23
# 18                7km WNW of The Geysers, CA    earthquake            0.56
# 19               253km ESE of Kodiak, Alaska    earthquake             NaN
# 20               122km SE of McGrath, Alaska    earthquake             NaN
# 21           11km NNE of Borrego Springs, CA    earthquake            0.29
# 22          13km NNW of Kasiguncu, Indonesia    earthquake            6.00
# 23                         4km W of Cobb, CA    earthquake            0.35
# 24               4km ESE of Round Valley, CA    earthquake            0.27
# 25            38km S of Sandy Valley, Nevada     explosion             NaN
# 26                  12km SE of Livermore, CA    earthquake            0.59
# 27                     7km ESE of Bonita, CA  quarry blast            0.64
# 28               14km SE of Waikoloa, Hawaii    earthquake            0.53
# 29                        8km E of Lebec, CA  quarry blast            0.44
# ...                                      ...           ...             ...
# 9740              87km NW of Nikiski, Alaska    earthquake             NaN
# 9741          99km SSW of Sand Point, Alaska    earthquake             NaN
# 9742                  14km SE of Bodfish, CA    earthquake            0.21
# 9743             162km NE of Nord, Greenland    earthquake           11.60
# 9744           7km W of Dutch Harbor, Alaska    earthquake             NaN
# 9745              54km NNW of Valdez, Alaska    earthquake             NaN
# 9746              10km SSW of Tres Pinos, CA    earthquake            0.22
# 9747  70km ENE of Kainantu, Papua New Guinea    earthquake           14.80
# 9748           24km ESE of Hawthorne, Nevada    earthquake             NaN
# 9749        12km NW of Virginia City, Nevada    earthquake             NaN
# 9750       42km NW of Aguadilla, Puerto Rico    earthquake            1.90
# 9751           82km E of Old Iliamna, Alaska    earthquake             NaN
# 9752              9km ESE of Yorba Linda, CA    earthquake            0.22
# 9753        50km WSW of Anchor Point, Alaska    earthquake             NaN
# 9754                       8km W of Cobb, CA    earthquake            0.36
# 9755             40km S of Goldfield, Nevada    earthquake             NaN
# 9756        12km NW of Virginia City, Nevada    earthquake             NaN
# 9757               6km NW of The Geysers, CA    earthquake            0.35
# 9758              9km WSW of Lytle Creek, CA    earthquake            0.11
# 9759                  9km ENE of Aguanga, CA    earthquake            0.25
# 9760                33km WNW of Petrolia, CA    earthquake            1.00
# 9761             53km W of Anchorage, Alaska    earthquake             NaN
# 9762             5km NE of Coso Junction, CA    earthquake            0.15
# 9763               1km NE of The Geysers, CA    earthquake            0.20
# 9764               1km NE of The Geysers, CA    earthquake            0.14
# 9765           13km ESE of Mammoth Lakes, CA    earthquake            0.36
# 9766               3km S of Sherman Oaks, CA    earthquake            0.26
# 9767             5km SW of Mammoth Lakes, CA    earthquake            0.41
# 9768               68km S of Yakutat, Alaska    earthquake            2.40
# 9769                32km NW of Kernville, CA    earthquake            0.24
#
#      depthError  magError  magNst     status  locationSource magSource
# 0          0.83     0.120     7.0  automatic              hv        hv
# 1          0.50       NaN     NaN  automatic              ak        ak
# 2         31.61     0.111     2.0  automatic              ci        ci
# 3          0.67     0.227    20.0   reviewed              ci        ci
# 4          2.10     0.600     3.0   reviewed              nn        nn
# 5          0.70       NaN     NaN  automatic              ak        ak
# 6          1.16     0.480     2.0  automatic              nc        nc
# 7          1.90     0.069    64.0   reviewed              us        us
# 8          0.40     0.202    23.0   reviewed              ci        ci
# 9          0.20       NaN     NaN  automatic              ak        ak
# 10         0.20       NaN     NaN  automatic              ak        ak
# 11         1.62     0.157    26.0   reviewed              nc        nc
# 12         0.44     0.211    14.0   reviewed              ci        ci
# 13         0.72     0.140    14.0   reviewed              ci        ci
# 14         1.12     0.108    10.0   reviewed              ci        ci
# 15        10.76     0.130     6.0  automatic              nc        nc
# 16         1.00       NaN     NaN  automatic              ak        ak
# 17         0.43     0.126    15.0   reviewed              ci        ci
# 18         0.92       NaN     1.0  automatic              nc        nc
# 19        10.70       NaN     NaN  automatic              ak        ak
# 20         0.30       NaN     NaN  automatic              ak        ak
# 21         0.59     0.081    23.0   reviewed              ci        ci
# 22         6.60     0.085    41.0   reviewed              us        us
# 23         0.63     0.090     2.0  automatic              nc        nc
# 24         0.78     0.150    22.0  automatic              nc        nc
# 25         0.00     0.240    10.0   reviewed              nn        nn
# 26         1.11     0.090     7.0  automatic              nc        nc
# 27        31.61     0.085     8.0   reviewed              ci        ci
# 28         0.83     0.079    18.0   reviewed              hv        hv
# 29        31.61     0.057    11.0   reviewed              ci        ci
# ...         ...       ...     ...        ...             ...       ...
# 9740       0.40       NaN     NaN   reviewed              ak        ak
# 9741       0.80       NaN     NaN   reviewed              ak        ak
# 9742       0.32     0.160    11.0   reviewed              ci        ci
# 9743       5.20     0.049   126.0   reviewed              us        us
# 9744       0.40       NaN     NaN   reviewed              ak        ak
# 9745       0.30       NaN     NaN   reviewed              ak        ak
# 9746       0.72     0.253    27.0   reviewed              nc        nc
# 9747       9.80     0.123    19.0   reviewed              us        us
# 9748      20.30     0.420     3.0   reviewed              nn        nn
# 9749       1.00     0.480     8.0   reviewed              nn        nn
# 9750       1.53     0.390    12.0   reviewed              pr        pr
# 9751       0.20       NaN     NaN   reviewed              ak        ak
# 9752       0.40     0.122    20.0   reviewed              ci        ci
# 9753       0.20       NaN     NaN   reviewed              ak        ak
# 9754       0.94       NaN     1.0   reviewed              nc        nc
# 9755       2.30     0.150     5.0   reviewed              nn        nn
# 9756       1.50     1.090     5.0   reviewed              nn        nn
# 9757       0.76     0.040     4.0  automatic              nc        nc
# 9758       0.28     0.108   143.0   reviewed              ci        ci
# 9759       1.09     0.108    20.0   reviewed              ci        ci
# 9760       1.97     0.177    31.0   reviewed              nc        nc
# 9761       0.30       NaN     NaN   reviewed              ak        ak
# 9762       0.30     0.150    34.0   reviewed              ci        ci
# 9763       0.38     0.215     8.0   reviewed              nc        nc
# 9764       0.31     0.292    19.0   reviewed              nc        nc
# 9765       0.47     0.173    15.0   reviewed              nc        nc
# 9766       0.36     0.185    14.0   reviewed              ci        ci
# 9767       0.27     0.324    11.0   reviewed              nc        nc
# 9768       5.20       NaN     NaN   reviewed              ak        ak
# 9769       0.80     0.195    13.0   reviewed              ci        ci
#
# [9770 rows x 22 columns]

# %%
print(list)
# Out:
# ['Afganistan', 'Asia', 4, 187.55, 1987, 6.2]

# %% [markdown]
# # .iloc()
# #.iloc() - integer based position indexing
# #dataframe.iloc[row selection,column selection]
# my_file.iloc[0,2]

# %%
my_file.iloc[0:5,2]
# Out:
# 0    1952
# 1    1957
# 2    1962
# 3    1967
# 4    1972
# Name: year, dtype: int64

# %%
my_file.iloc[:,2]
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
# 5       1977
# 6       1982
# 7       1987
# 8       1992
# 9       1997
# 10      2002
# 11      2007
# 12      1952
# 13      1957
# 14      1962
# 15      1967
# 16      1972
# 17      1977
# 18      1982
# 19      1987
# 20      1992
# 21      1997
# 22      2002
# 23      2007
# 24      1952
# 25      1957
# 26      1962
# 27      1967
# 28      1972
# 29      1977
#         ...
# 1674    1982
# 1675    1987
# 1676    1992
# 1677    1997
# 1678    2002
# 1679    2007
# 1680    1952
# 1681    1957
# 1682    1962
# 1683    1967
# 1684    1972
# 1685    1977
# 1686    1982
# 1687    1987
# 1688    1992
# 1689    1997
# 1690    2002
# 1691    2007
# 1692    1952
# 1693    1957
# 1694    1962
# 1695    1967
# 1696    1972
# 1697    1977
# 1698    1982
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
my_file.iloc[0:2,1:4]
# Out:
#   continent  year  lifeExp
# 0      Asia  1952   28.801
# 1      Asia  1957   30.332

# %%
my_file.iloc[[0,1,5],[2,5]]
# Out:
#    year   gdpPercap
# 0  1952  779.445314
# 1  1957  820.853030
# 5  1977  786.113360

# %% [markdown]
# # .loc[]

# %%
# .loc[] - label based postion indexing
# .loc[row selection, column selection]
my_file.loc[:,['year']]

# %%
my_file.loc[:,['year']]
my_file.loc[:,['year','continent']]
my_file.loc[1:5,['year','continent']]
# Out:
#    year continent
# 1  1957      Asia
# 2  1962      Asia
# 3  1967      Asia
# 4  1972      Asia
# 5  1977      Asia

# %%
# .loc[] - label based postion indexing
# .loc[row selection, column selection]
my_file.loc[my_file['country']=="Afghanistan"]
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816  978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957  852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921  649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923  974.580338

# %%
ls=my_file['country']=="Afghanistan"

# %%
print(ls)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# 1679    False
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# 1691    False
# 1692    False
# 1693    False
# 1694    False
# 1695    False
# 1696    False
# 1697    False
# 1698    False
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %% [markdown]
# # importing packages

# %%
#This is lifeExpPlot.py

# importing packages
import pandas as pd
import matplotlib.pyplot as plt

#reading file
my_file=pd.read_table("gapminder.txt")

#subsetting

Canada= my_file.loc[my_file['country']=="Canada"]

# %%
print(Canada)
# Out:
#     country continent  year  lifeExp       pop    gdpPercap
# 240  Canada  Americas  1952   68.750  14785584  11367.16112
# 241  Canada  Americas  1957   69.960  17010154  12489.95006
# 242  Canada  Americas  1962   71.300  18985849  13462.48555
# 243  Canada  Americas  1967   72.130  20819767  16076.58803
# 244  Canada  Americas  1972   72.880  22284500  18970.57086
# 245  Canada  Americas  1977   74.210  23796400  22090.88306
# 246  Canada  Americas  1982   75.760  25201900  22898.79214
# 247  Canada  Americas  1987   76.860  26549700  26626.51503
# 248  Canada  Americas  1992   77.950  28523502  26342.88426
# 249  Canada  Americas  1997   78.610  30305843  28954.92589
# 250  Canada  Americas  2002   79.770  31902268  33328.96507
# 251  Canada  Americas  2007   80.653  33390141  36319.23501

# %%
#This is lifeExpPlot.py

# importing packages
import pandas as pd
import matplotlib.pyplot as plt

#reading file
my_file=pd.read_table("gapminder.txt")

#subsetting

Canada= my_file.loc[my_file['country']=="Canada"]

#plotting
Canada.plot.line(x="year", y="lifeExp", label="Life Expectancy", figsize=(8,6))
plt.suptitle("Life Expectancy in Canada over the years", fontsize= 20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Life Expectancy", fontsize=16)
plt.show()

# %%
#This is lifeExpPlot.py

# importing packages
import pandas as pd
import matplotlib.pyplot as plt

#reading file
my_file=pd.read_table("gapminder.txt")

#subsetting

Canada= my_file.loc[my_file['country']=="Canada"]

#plotting
Canada.plot.line(x="year", y="lifeExp", label="Life Expectancy", figsize=(8,6))
plt.suptitle("Life Expectancy in Canada over the years", fontsize= 20)
plt.xlabel("Year", fontsize=16)
plt.ylabel("Life Expectancy", fontsize=16)
plt.show()
